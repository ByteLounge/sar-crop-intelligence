# %% [markdown]
# # ANRF AISEHack 2.0 SAR Crop Mapping
# This notebook serves as a walk-through for exploring the Capella SAR imagery crop mapping results.

# %%
import pandas as pd
sub = pd.read_csv('../submission.csv')
print(sub.head())
